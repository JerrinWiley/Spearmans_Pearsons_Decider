# %%
#makes import work
import pandas as pd
from scipy import stats
import numpy as np
import statistics
import copy
import scipy
import csv
import statsmodels.stats.multitest as multi

filename = "MicrobiomexMetabolome.xlsx"
data = pd.read_excel(filename)
# data += 0.0000000000001

# %%
class DataColumn:
    def __init__(self, name, original):
        self.name = name
        self.original = original
        self.current = copy.deepcopy(original)
        self.path = []
        
    def info(self):
        print('name: {}\noriginal: {}\nCurrent: {}'.format(self.name, self.original, self.current))
   
    def shapiro(self):
            return stats.shapiro(self.current).pvalue
        
    def log_transform(self):
        self.current = np.log10(self.current)

# %%
class ComparisonResults:
    def __init__(self, name1, name2, path, testName, rho, pval, n, f_test_progression, r_squared):
        self.dataName1 = name1
        self.dataName2 = name2
        self.path = path
        self.testName = testName
        self.rho = rho
        self.pval = pval
        self.n = n
        self.f_test_progression = f_test_progression
        self.r_squared = r_squared[0,1]**2
    
    def update_n(self, n):
        self.n = n
        
#     def info(self):
#         print('{} & {}\ntest: {}\nRho: {}\nP value: {}'.format(self.dataName1, self.dataName2, self.testName, self.rho, self.pval))
#         return
    
#     def to_csv(self):
#         return '{},{},{},{},{}'.format(self.dataName1, self.dataName2, self.testName, self.rho, self.pval)

# %%
def xor_less_than_p(a, b, p):
    a = float(a)
    b = float(b)
    if a < p and b >= p:
        return True
    elif b < p and a >= p:
        return True
    else:
        return False

# %%
def f_test(x, y):
    x = np.array(x)
    y = np.array(y)
    var1 = np.var(x, ddof=1)
    var2 = np.var(y, ddof=1)
    if var1 >= var2:
        f = var1/var2 #calculate F test statistic
    elif var1 < var2:
        f = var2/var1 #calculate F test statistic 
    else:
        print('f-test error')
    dfn = x.size-1 #define degrees of freedom numerator 
    dfd = y.size-1 #define degrees of freedom denominator 
    p = 1-scipy.stats.f.cdf(f, dfn, dfd) #find p-value of F test statistic 
    return p

# %%
def test_decider(dataA, dataB):
    f_test_progression = []
    path = []
    
    data1 = copy.deepcopy(dataA)
    data2 = copy.deepcopy(dataB)
    dataArray1 = data1.original
    dataArray2 = data2.original
    
    # eliminate NaN
    df_both = pd.concat([dataArray1, dataArray2], axis=1)
    df_both = df_both.apply (pd.to_numeric, errors='coerce')
    df_both = df_both.dropna()
    df_both = df_both.reset_index(drop=True)
    df_both += 0.0000000000001
    
    data1 = DataColumn(data1.name, df_both.iloc[:,0])
    data2 = DataColumn(data2.name, df_both.iloc[:,1])

    n = data1.original.size
    p = 0.05000000000000000000000000000000000000000000000000
    
    if data1.original.min()< 0 or data2.original.min()< 0:
        path.append('Negative values')
        name1 = data1.name
        name2 = data2.name
        testName = 'Spearmans'
        rho, pval = stats.spearmanr(data1.original,data2.original)
        r_squared = np.corrcoef(data1.original,data2.original)
        return(ComparisonResults(name1, name2, path, testName, rho, pval,n, f_test_progression, r_squared))
    
    if xor_less_than_p(data1.shapiro(),data2.shapiro(),p):
        path.append('A')
        if data1.shapiro() < p:
            data1.log_transform()
        elif data2.shapiro() < p:
            data2.log_transform()
        else:
            print('error')
        if data1.shapiro() < p or data2.shapiro() < p:
            path.append('D')
            name1 = data1.name
            name2 = data2.name
            testName = 'Spearmans'
            rho, pval = stats.spearmanr(data1.original,data2.original)
            r_squared = np.corrcoef(data1.original,data2.original)
            return(ComparisonResults(name1, name2, path, testName, rho, pval,n, f_test_progression, r_squared))
#             print('{} & {}:\nspearmans: {}'.format(data1.name, data2.name, path))
#             rho, pval = stats.spearmanr(data1.original,data2.original)
#             print('Rho: {}\nP val: {}\n'.format(rho, pval ))
            
        elif data1.shapiro() > p and data2.shapiro() > p:
            path.append('E')
            f_p = f_test(data1.current, data2.current)
            f_test_progression.append(f_p)
            if f_p > p:
                path.append('L')
                name1 = data1.name
                name2 = data2.name
                testName = 'Pearsons'
                rho, pval = stats.pearsonr(data1.current,data2.current)
                r_squared = np.corrcoef(data1.current,data2.current)
                return(ComparisonResults(name1, name2, path, testName, rho, pval,n, f_test_progression, r_squared))
#                 print('{} & {}:\npearsons: {}'.format(data1.name, data2.name, path))
#                 rho, pval = stats.pearsonr(data1.current,data2.current)
#                 print('Rho: {}\nP val: {}\n'.format(rho, pval ))
            elif f_p < p:
                path.append('H')
                if data1.current.equals(data1.original):
                    data1.log_transform()
                elif data2.current.equals(data2.original):
                    data2.log_transform()
                else:
                    print('error')
                if data1.shapiro() < p or data2.shapiro() < p:
                    path.append('G')
                    name1 = data1.name
                    name2 = data2.name
                    testName = 'Spearmans'
                    rho, pval = stats.spearmanr(data1.original,data2.original)
                    r_squared = np.corrcoef(data1.original,data2.original)
                    return(ComparisonResults(name1, name2, path, testName, rho, pval,n, f_test_progression, r_squared))
                elif data1.shapiro() > p and data2.shapiro() > p:
                    path.append('K')
                    f_p = f_test(data1.current, data2.current)
                    if f_p > p:
                        path.append('O')
                        name1 = data1.name
                        name2 = data2.name
                        testName = 'Pearsons'
                        rho, pval = stats.pearsonr(data1.current,data2.current)
                        r_squared = np.corrcoef(data1.current,data2.current)
                        return(ComparisonResults(name1, name2, path, testName, rho, pval,n, f_test_progression, r_squared))
                    elif f_p < p:
                        path.append('N')
                        name1 = data1.name
                        name2 = data2.name
                        testName = 'Spearmans'
                        rho, pval = stats.spearmanr(data1.original,data2.original)
                        r_squared = np.corrcoef(data1.original,data2.original)
                        return(ComparisonResults(name1, name2, path, testName, rho, pval,n, f_test_progression, r_squared))
                    else:
                        print('error')
                        
                else:
                    print('error')
            else:
                print('error')
        else:
            print('error')
    elif data1.shapiro() < p and data2.shapiro() < p:
        path.append('B')
        data1.log_transform()
        data2.log_transform()
        if data1.shapiro() < p or data2.shapiro() < p:
            path.append('M')
            name1 = data1.name
            name2 = data2.name
            testName = 'Spearmans'
            rho, pval = stats.spearmanr(data1.original,data2.original)
            r_squared = np.corrcoef(data1.original,data2.original)
            return(ComparisonResults(name1, name2, path, testName, rho, pval,n, f_test_progression, r_squared))
        elif data1.shapiro() > p and data2.shapiro() > p:
            path.append('I')
            f_p = f_test(data1.current, data2.current)
            f_test_progression.append(f_p)
            if f_p < p:
                path.append('P')
                name1 = data1.name
                name2 = data2.name
                testName = 'Spearmans'
                rho, pval = stats.spearmanr(data1.original,data2.original)
                r_squared = np.corrcoef(data1.original,data2.original)
                return(ComparisonResults(name1, name2, path, testName, rho, pval,n, f_test_progression, r_squared))
            elif f_p > p:
                path.append('Q')
                name1 = data1.name
                name2 = data2.name
                testName = 'Pearsons'
                rho, pval = stats.pearsonr(data1.current,data2.current)
                r_squared = np.corrcoef(data1.current,data2.current)
                return(ComparisonResults(name1, name2, path, testName, rho, pval,n, f_test_progression, r_squared))
            else:
                print('error')
        else:
            print('error')
    elif data1.shapiro() > p and data2.shapiro() > p:
        path.append('C')
        f_p = f_test(data1.current, data2.current)
        f_test_progression.append(f_p)
        if f_p < p:
            path.append('F')
            data1.log_transform()
            data2.log_transform()
            if data1.shapiro() < p or data2.shapiro() < p:
                path.append('M')
                name1 = data1.name
                name2 = data2.name
                testName = 'Spearmans'
                rho, pval = stats.spearmanr(data1.original,data2.original)
                r_squared = np.corrcoef(data1.original,data2.original)
                return(ComparisonResults(name1, name2, path, testName, rho, pval,n, f_test_progression, r_squared))
            elif data1.shapiro() > p and data2.shapiro() > p:
                path.append('I')
                f_p = f_test(data1.current, data2.current)
                f_test_progression.append(f_p)
                if f_p < p:
                    path.append('P')
                    name1 = data1.name
                    name2 = data2.name
                    testName = 'Spearmans'
                    rho, pval = stats.spearmanr(data1.original,data2.original)
                    r_squared = np.corrcoef(data1.original,data2.original)
                    return(ComparisonResults(name1, name2, path, testName, rho, pval,n, f_test_progression, r_squared))
                elif f_p > p:
                    path.append('Q')
                    name1 = data1.name
                    name2 = data2.name
                    testName = 'Pearsons'
                    rho, pval = stats.pearsonr(data1.current,data2.current)
                    r_squared = np.corrcoef(data1.current,data2.current)
                    return(ComparisonResults(name1, name2, path, testName, rho, pval,n, f_test_progression, r_squared))
                else:
                    print('error')
            else:
                print('error')
        elif f_p > p:
            path.append('J')
            name1 = data1.name
            name2 = data2.name
            testName = 'Pearsons'
            rho, pval = stats.pearsonr(data1.current,data2.current)
            r_squared = np.corrcoef(data1.current,data2.current)
            return(ComparisonResults(name1, name2, path, testName, rho, pval,n, f_test_progression, r_squared))
        else:
            print('error')
    else:
        print('error')

# %%
dataName = data.columns.values
dataArray = []

# %%
for i, name in enumerate(list(dataName)):
#     dataArray.append(DataColumn(name, data[name].tolist()))
    dataArray.append(DataColumn(name, data[name]))

# %%
results = []

# %%
attributeCount = len(dataArray)
for i in range(attributeCount):
    for j in range(i,attributeCount):
        if i != j:  
            results.append(test_decider(dataArray[i], dataArray[j]))

# %%
p_val_list = []
for item in results:
    p_val_list.append(item.pval)
Corrected_P_Vals = multi.multipletests(p_val_list,method='fdr_bh')[1]

# %%
results_filename = filename[:-5]+'_results.csv'
with open(results_filename, mode='w', newline='') as output_file:
    result_writer = csv.writer(output_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    result_writer.writerow(['Attribute 1', 'Attribute 2', 'Test Run', 'n', 'Rho', 'P Value', 'Corrected P Value', ' R-squared', 'Path', 'F-Test Progression'])
    for i, item in enumerate(results):
        result_writer.writerow([item.dataName1, item.dataName2, item.testName, item.n, item.rho, item.pval, Corrected_P_Vals[i], item.r_squared,item.path, item.f_test_progression])
